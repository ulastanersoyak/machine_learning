# %%
import torch as tc
from torch import nn
device = "cuda" if tc.cuda.is_available() else "cpu"
print(f"current device is {device} \n")


import sklearn
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
data_count = 2000
x,y = make_circles(
    data_count,
    noise=0.08)

import pandas as pd
circles = pd.DataFrame({"X1":x[:,0],"X2":x[:,1],"label":y})
circles.head(10)
# Out:
# current device is cuda
#          X1        X2  label
# 0  1.027156  0.310021      0
# 1  0.754920 -0.197565      1
# 2 -0.465816  0.394183      1
# 3 -0.279969 -1.140030      0
# 4 -0.774389 -0.194548      1
# 5  0.363420 -0.644005      1
# 6 -0.365902  0.732706      1
# 7  1.042087 -0.173635      0
# 8 -0.008963  0.823022      1
# 9  0.341553  0.851805      0

# %%
import matplotlib.pyplot as plt

plt.scatter(x=x[:,0],
            y=x[:,1],
            c=y,
            cmap = plt.cm.RdYlBu)

# %%
x = tc.from_numpy(x).type(tc.float)
y = tc.from_numpy(y).type(tc.float)
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.3)
len(x_train),len(x_test),len(y_train),len(y_test)
# Out:
# (1400, 600, 1400, 600)

# %%
class Model(nn.Module):
  def __init__(self):
    super().__init__()
    self.layer_1 = nn.Linear(in_features=2,out_features=32)
    self.layer_2 = nn.Linear(in_features=32,out_features=32)
    self.layer_3 = nn.Linear(in_features=32,out_features=1)
    self.relu = nn.ReLU()

  def forward(self,x):
    return self.layer_3(self.relu(self.layer_2(self.relu(self.layer_1(x)))))
model = Model().to(device)
print(model)
# Out:
# Model(
#   (layer_1): Linear(in_features=2, out_features=32, bias=True)
#   (layer_2): Linear(in_features=32, out_features=32, bias=True)
#   (layer_3): Linear(in_features=32, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
loss_function = nn.BCEWithLogitsLoss()
optimizer = tc.optim.SGD(model.parameters(),lr=0.05)

accuracy_function = lambda y_result,y_pred : (tc.eq(y_result,y_pred).sum().item()/len(y_pred))*100

# %%
epochs = 20_000

x_train , y_train = x_train.to(device) , y_train.to(device)
x_test , y_test = x_test.to(device) , y_test.to(device)

for epoch in range(epochs+1):

  y_result = model(x_train).squeeze()
  y_pred = tc.round(tc.sigmoid(y_result))


  loss = loss_function(y_result , y_train)
  accuracy = accuracy_function(y_train,y_pred)

  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

  model.eval()
  with tc.inference_mode():
    test_result = model(x_test).squeeze()
    test_pred = tc.round(tc.sigmoid(test_result))
    test_loss = loss_function(test_result,y_test)
    test_accuracy = accuracy_function(y_test,test_pred)

  if epoch % 100 == 0:
    print(f"epoch:{epoch} loss:{loss:.5f} accuracy:%{accuracy:.5f} test loss:{test_loss:.5f} test accuracy:%{test_accuracy:.2f}\n")
# Out:
# epoch:0 loss:0.24925 accuracy:%89.00000 test loss:0.25768 test accuracy:%89.50
#
# epoch:100 loss:0.24824 accuracy:%88.85714 test loss:0.25780 test accuracy:%89.50
#
# epoch:200 loss:0.24823 accuracy:%88.92857 test loss:0.25785 test accuracy:%89.67
#
# epoch:300 loss:0.24823 accuracy:%88.85714 test loss:0.25785 test accuracy:%89.50
#
# epoch:400 loss:0.24822 accuracy:%88.92857 test loss:0.25786 test accuracy:%89.83
#
# epoch:500 loss:0.24822 accuracy:%88.92857 test loss:0.25784 test accuracy:%89.83
#
# epoch:600 loss:0.24821 accuracy:%88.85714 test loss:0.25781 test accuracy:%89.50
#
# epoch:700 loss:0.24821 accuracy:%88.85714 test loss:0.25782 test accuracy:%89.50
#
# epoch:800 loss:0.24820 accuracy:%88.85714 test loss:0.25780 test accuracy:%89.50
#
# epoch:900 loss:0.24820 accuracy:%88.92857 test loss:0.25781 test accuracy:%89.83
#
# epoch:1000 loss:0.24819 accuracy:%88.85714 test loss:0.25779 test accuracy:%89.50
#
# epoch:1100 loss:0.24819 accuracy:%88.85714 test loss:0.25779 test accuracy:%89.50
#
# epoch:1200 loss:0.24819 accuracy:%88.85714 test loss:0.25779 test accuracy:%89.50
#
# epoch:1300 loss:0.24818 accuracy:%88.85714 test loss:0.25777 test accuracy:%89.67
#
# epoch:1400 loss:0.24818 accuracy:%88.85714 test loss:0.25776 test accuracy:%89.67
#
# epoch:1500 loss:0.24817 accuracy:%88.92857 test loss:0.25773 test accuracy:%89.67
#
# epoch:1600 loss:0.24817 accuracy:%88.92857 test loss:0.25775 test accuracy:%89.67
#
# epoch:1700 loss:0.24816 accuracy:%88.92857 test loss:0.25772 test accuracy:%89.67
#
# epoch:1800 loss:0.24816 accuracy:%88.92857 test loss:0.25772 test accuracy:%89.67
#
# epoch:1900 loss:0.24816 accuracy:%88.92857 test loss:0.25771 test accuracy:%89.67
#
# epoch:2000 loss:0.24815 accuracy:%88.92857 test loss:0.25770 test accuracy:%89.67
#
# epoch:2100 loss:0.24815 accuracy:%88.92857 test loss:0.25770 test accuracy:%89.67
#
# epoch:2200 loss:0.24814 accuracy:%88.92857 test loss:0.25769 test accuracy:%89.67
#
# epoch:2300 loss:0.24814 accuracy:%88.92857 test loss:0.25771 test accuracy:%89.67
#
# epoch:2400 loss:0.24814 accuracy:%88.92857 test loss:0.25770 test accuracy:%89.67
#
# epoch:2500 loss:0.24813 accuracy:%88.92857 test loss:0.25769 test accuracy:%89.67
#
# epoch:2600 loss:0.24813 accuracy:%88.92857 test loss:0.25768 test accuracy:%89.67
#
# epoch:2700 loss:0.24812 accuracy:%88.92857 test loss:0.25767 test accuracy:%89.67
#
# epoch:2800 loss:0.24812 accuracy:%88.92857 test loss:0.25765 test accuracy:%89.67
#
# epoch:2900 loss:0.24812 accuracy:%88.92857 test loss:0.25767 test accuracy:%89.67
#
# epoch:3000 loss:0.24811 accuracy:%88.92857 test loss:0.25765 test accuracy:%89.67
#
# epoch:3100 loss:0.24811 accuracy:%88.92857 test loss:0.25765 test accuracy:%89.67
#
# epoch:3200 loss:0.24810 accuracy:%88.92857 test loss:0.25764 test accuracy:%89.67
#
# epoch:3300 loss:0.24810 accuracy:%88.92857 test loss:0.25763 test accuracy:%89.67
#
# epoch:3400 loss:0.24810 accuracy:%88.92857 test loss:0.25763 test accuracy:%89.67
#
# epoch:3500 loss:0.24809 accuracy:%88.92857 test loss:0.25763 test accuracy:%89.67
#
# epoch:3600 loss:0.24809 accuracy:%88.92857 test loss:0.25763 test accuracy:%89.67
#
# epoch:3700 loss:0.24808 accuracy:%88.92857 test loss:0.25763 test accuracy:%89.67
#
# epoch:3800 loss:0.24808 accuracy:%88.85714 test loss:0.25761 test accuracy:%89.67
#
# epoch:3900 loss:0.24808 accuracy:%88.85714 test loss:0.25761 test accuracy:%89.67
#
# epoch:4000 loss:0.24807 accuracy:%88.85714 test loss:0.25761 test accuracy:%89.67
#
# epoch:4100 loss:0.24807 accuracy:%88.85714 test loss:0.25760 test accuracy:%89.67
#
# epoch:4200 loss:0.24806 accuracy:%88.85714 test loss:0.25759 test accuracy:%89.67
#
# epoch:4300 loss:0.24806 accuracy:%88.85714 test loss:0.25759 test accuracy:%89.67
#
# epoch:4400 loss:0.24806 accuracy:%88.85714 test loss:0.25758 test accuracy:%89.67
#
# epoch:4500 loss:0.24805 accuracy:%88.85714 test loss:0.25757 test accuracy:%89.67
#
# epoch:4600 loss:0.24805 accuracy:%88.85714 test loss:0.25758 test accuracy:%89.67
#
# epoch:4700 loss:0.24805 accuracy:%88.85714 test loss:0.25759 test accuracy:%89.67
#
# epoch:4800 loss:0.24804 accuracy:%88.85714 test loss:0.25757 test accuracy:%89.67
#
# epoch:4900 loss:0.24804 accuracy:%88.85714 test loss:0.25758 test accuracy:%89.67
#
# epoch:5000 loss:0.24803 accuracy:%88.85714 test loss:0.25755 test accuracy:%89.67
#
# epoch:5100 loss:0.24803 accuracy:%88.85714 test loss:0.25755 test accuracy:%89.67
#
# epoch:5200 loss:0.24803 accuracy:%88.85714 test loss:0.25757 test accuracy:%89.67
#
# epoch:5300 loss:0.24802 accuracy:%88.92857 test loss:0.25758 test accuracy:%89.67
#
# epoch:5400 loss:0.24802 accuracy:%88.92857 test loss:0.25757 test accuracy:%89.67
#
# epoch:5500 loss:0.24801 accuracy:%88.92857 test loss:0.25755 test accuracy:%89.67
#
# epoch:5600 loss:0.24801 accuracy:%88.92857 test loss:0.25755 test accuracy:%89.67
#
# epoch:5700 loss:0.24801 accuracy:%88.92857 test loss:0.25757 test accuracy:%89.67
#
# epoch:5800 loss:0.24800 accuracy:%88.92857 test loss:0.25755 test accuracy:%89.67
#
# epoch:5900 loss:0.24800 accuracy:%88.92857 test loss:0.25755 test accuracy:%89.67
#
# epoch:6000 loss:0.24799 accuracy:%88.92857 test loss:0.25754 test accuracy:%89.67
#
# epoch:6100 loss:0.24799 accuracy:%88.92857 test loss:0.25756 test accuracy:%89.67
#
# epoch:6200 loss:0.24799 accuracy:%88.92857 test loss:0.25757 test accuracy:%89.67
#
# epoch:6300 loss:0.24798 accuracy:%88.92857 test loss:0.25754 test accuracy:%89.67
#
# epoch:6400 loss:0.24798 accuracy:%88.92857 test loss:0.25754 test accuracy:%89.67
#
# epoch:6500 loss:0.24798 accuracy:%88.92857 test loss:0.25754 test accuracy:%89.67
#
# epoch:6600 loss:0.24797 accuracy:%88.92857 test loss:0.25754 test accuracy:%89.67
#
# epoch:6700 loss:0.24797 accuracy:%88.92857 test loss:0.25754 test accuracy:%89.67
#
# epoch:6800 loss:0.24797 accuracy:%88.92857 test loss:0.25752 test accuracy:%89.67
#
# epoch:6900 loss:0.24796 accuracy:%88.92857 test loss:0.25754 test accuracy:%89.67
#
# epoch:7000 loss:0.24796 accuracy:%88.92857 test loss:0.25752 test accuracy:%89.67
#
# epoch:7100 loss:0.24795 accuracy:%88.92857 test loss:0.25753 test accuracy:%89.67
#
# epoch:7200 loss:0.24795 accuracy:%88.92857 test loss:0.25751 test accuracy:%89.67
#
# epoch:7300 loss:0.24795 accuracy:%88.92857 test loss:0.25752 test accuracy:%89.67
#
# epoch:7400 loss:0.24794 accuracy:%88.92857 test loss:0.25753 test accuracy:%89.67
#
# epoch:7500 loss:0.24794 accuracy:%88.92857 test loss:0.25750 test accuracy:%89.67
#
# epoch:7600 loss:0.24793 accuracy:%88.92857 test loss:0.25750 test accuracy:%89.67
#
# epoch:7700 loss:0.24793 accuracy:%88.92857 test loss:0.25751 test accuracy:%89.67
#
# epoch:7800 loss:0.24793 accuracy:%88.92857 test loss:0.25749 test accuracy:%89.67
#
# epoch:7900 loss:0.24792 accuracy:%88.92857 test loss:0.25749 test accuracy:%89.67
#
# epoch:8000 loss:0.24792 accuracy:%88.92857 test loss:0.25750 test accuracy:%89.67
#
# epoch:8100 loss:0.24792 accuracy:%88.92857 test loss:0.25750 test accuracy:%89.67
#
# epoch:8200 loss:0.24791 accuracy:%88.92857 test loss:0.25748 test accuracy:%89.67
#
# epoch:8300 loss:0.24791 accuracy:%88.92857 test loss:0.25750 test accuracy:%89.67
#
# epoch:8400 loss:0.24790 accuracy:%88.92857 test loss:0.25751 test accuracy:%89.67
#
# epoch:8500 loss:0.24790 accuracy:%88.92857 test loss:0.25748 test accuracy:%89.67
#
# epoch:8600 loss:0.24790 accuracy:%88.92857 test loss:0.25747 test accuracy:%89.67
#
# epoch:8700 loss:0.24789 accuracy:%88.92857 test loss:0.25748 test accuracy:%89.67
#
# epoch:8800 loss:0.24789 accuracy:%88.92857 test loss:0.25747 test accuracy:%89.67
#
# epoch:8900 loss:0.24788 accuracy:%88.92857 test loss:0.25749 test accuracy:%89.67
#
# epoch:9000 loss:0.24788 accuracy:%88.92857 test loss:0.25748 test accuracy:%89.67
#
# epoch:9100 loss:0.24788 accuracy:%88.92857 test loss:0.25746 test accuracy:%89.67
#
# epoch:9200 loss:0.24787 accuracy:%88.92857 test loss:0.25747 test accuracy:%89.67
#
# epoch:9300 loss:0.24787 accuracy:%88.85714 test loss:0.25746 test accuracy:%89.50
#
# epoch:9400 loss:0.24787 accuracy:%88.85714 test loss:0.25744 test accuracy:%89.50
#
# epoch:9500 loss:0.24786 accuracy:%88.85714 test loss:0.25742 test accuracy:%89.50
#
# epoch:9600 loss:0.24786 accuracy:%88.85714 test loss:0.25743 test accuracy:%89.50
#
# epoch:9700 loss:0.24785 accuracy:%88.92857 test loss:0.25743 test accuracy:%89.67
#
# epoch:9800 loss:0.24785 accuracy:%88.92857 test loss:0.25744 test accuracy:%89.67
#
# epoch:9900 loss:0.24785 accuracy:%88.92857 test loss:0.25743 test accuracy:%89.67
#
# epoch:10000 loss:0.24784 accuracy:%88.85714 test loss:0.25741 test accuracy:%89.50
#
# epoch:10100 loss:0.24784 accuracy:%88.92857 test loss:0.25740 test accuracy:%89.50
#
# epoch:10200 loss:0.24784 accuracy:%88.92857 test loss:0.25740 test accuracy:%89.50
#
# epoch:10300 loss:0.24783 accuracy:%88.92857 test loss:0.25739 test accuracy:%89.50
#
# epoch:10400 loss:0.24783 accuracy:%88.92857 test loss:0.25740 test accuracy:%89.50
#
# epoch:10500 loss:0.24782 accuracy:%88.92857 test loss:0.25743 test accuracy:%89.67
#
# epoch:10600 loss:0.24782 accuracy:%88.92857 test loss:0.25742 test accuracy:%89.67
#
# epoch:10700 loss:0.24782 accuracy:%88.92857 test loss:0.25740 test accuracy:%89.67
#
# epoch:10800 loss:0.24782 accuracy:%88.92857 test loss:0.25741 test accuracy:%89.67
#
# epoch:10900 loss:0.24781 accuracy:%88.92857 test loss:0.25739 test accuracy:%89.67
#
# epoch:11000 loss:0.24781 accuracy:%88.92857 test loss:0.25738 test accuracy:%89.50
#
# epoch:11100 loss:0.24780 accuracy:%88.92857 test loss:0.25733 test accuracy:%89.50
#
# epoch:11200 loss:0.24780 accuracy:%88.85714 test loss:0.25732 test accuracy:%89.50
#
# epoch:11300 loss:0.24779 accuracy:%88.85714 test loss:0.25728 test accuracy:%89.50
#
# epoch:11400 loss:0.24779 accuracy:%88.85714 test loss:0.25729 test accuracy:%89.50
#
# epoch:11500 loss:0.24778 accuracy:%88.92857 test loss:0.25731 test accuracy:%89.50
#
# epoch:11600 loss:0.24778 accuracy:%88.92857 test loss:0.25731 test accuracy:%89.50
#
# epoch:11700 loss:0.24778 accuracy:%88.92857 test loss:0.25730 test accuracy:%89.50
#
# epoch:11800 loss:0.24778 accuracy:%88.85714 test loss:0.25729 test accuracy:%89.50
#
# epoch:11900 loss:0.24777 accuracy:%88.92857 test loss:0.25730 test accuracy:%89.50
#
# epoch:12000 loss:0.24777 accuracy:%88.85714 test loss:0.25730 test accuracy:%89.50
#
# epoch:12100 loss:0.24777 accuracy:%88.92857 test loss:0.25729 test accuracy:%89.50
#
# epoch:12200 loss:0.24776 accuracy:%88.92857 test loss:0.25730 test accuracy:%89.50
#
# epoch:12300 loss:0.24776 accuracy:%88.92857 test loss:0.25730 test accuracy:%89.50
#
# epoch:12400 loss:0.24775 accuracy:%88.92857 test loss:0.25730 test accuracy:%89.50
#
# epoch:12500 loss:0.24775 accuracy:%88.92857 test loss:0.25729 test accuracy:%89.50
#
# epoch:12600 loss:0.24775 accuracy:%88.92857 test loss:0.25730 test accuracy:%89.50
#
# epoch:12700 loss:0.24774 accuracy:%88.92857 test loss:0.25729 test accuracy:%89.50
#
# epoch:12800 loss:0.24774 accuracy:%88.92857 test loss:0.25729 test accuracy:%89.50
#
# epoch:12900 loss:0.24774 accuracy:%88.92857 test loss:0.25730 test accuracy:%89.50
#
# epoch:13000 loss:0.24773 accuracy:%88.92857 test loss:0.25731 test accuracy:%89.50
#
# epoch:13100 loss:0.24773 accuracy:%88.92857 test loss:0.25730 test accuracy:%89.50
#
# epoch:13200 loss:0.24773 accuracy:%88.92857 test loss:0.25730 test accuracy:%89.50
#
# epoch:13300 loss:0.24773 accuracy:%88.92857 test loss:0.25729 test accuracy:%89.50
#
# epoch:13400 loss:0.24772 accuracy:%88.92857 test loss:0.25729 test accuracy:%89.50
#
# epoch:13500 loss:0.24772 accuracy:%88.92857 test loss:0.25730 test accuracy:%89.50
#
# epoch:13600 loss:0.24772 accuracy:%88.85714 test loss:0.25731 test accuracy:%89.50
#
# epoch:13700 loss:0.24771 accuracy:%88.92857 test loss:0.25731 test accuracy:%89.50
#
# epoch:13800 loss:0.24770 accuracy:%88.92857 test loss:0.25731 test accuracy:%89.50
#
# epoch:13900 loss:0.24770 accuracy:%88.92857 test loss:0.25728 test accuracy:%89.50
#
# epoch:14000 loss:0.24770 accuracy:%88.92857 test loss:0.25730 test accuracy:%89.50
#
# epoch:14100 loss:0.24770 accuracy:%88.92857 test loss:0.25729 test accuracy:%89.50
#
# epoch:14200 loss:0.24769 accuracy:%88.92857 test loss:0.25729 test accuracy:%89.50
#
# epoch:14300 loss:0.24769 accuracy:%88.92857 test loss:0.25728 test accuracy:%89.50
#
# epoch:14400 loss:0.24768 accuracy:%88.92857 test loss:0.25728 test accuracy:%89.50
#
# epoch:14500 loss:0.24768 accuracy:%88.92857 test loss:0.25729 test accuracy:%89.50
#
# epoch:14600 loss:0.24768 accuracy:%88.92857 test loss:0.25729 test accuracy:%89.50
#
# epoch:14700 loss:0.24768 accuracy:%88.92857 test loss:0.25728 test accuracy:%89.50
#
# epoch:14800 loss:0.24767 accuracy:%88.92857 test loss:0.25728 test accuracy:%89.50
#
# epoch:14900 loss:0.24767 accuracy:%88.92857 test loss:0.25728 test accuracy:%89.50
#
# epoch:15000 loss:0.24766 accuracy:%88.92857 test loss:0.25727 test accuracy:%89.50
#
# epoch:15100 loss:0.24766 accuracy:%88.92857 test loss:0.25727 test accuracy:%89.50
#
# epoch:15200 loss:0.24766 accuracy:%88.92857 test loss:0.25727 test accuracy:%89.50
#
# epoch:15300 loss:0.24765 accuracy:%88.92857 test loss:0.25728 test accuracy:%89.50
#
# epoch:15400 loss:0.24765 accuracy:%88.92857 test loss:0.25726 test accuracy:%89.50
#
# epoch:15500 loss:0.24765 accuracy:%88.92857 test loss:0.25727 test accuracy:%89.50
#
# epoch:15600 loss:0.24764 accuracy:%88.92857 test loss:0.25727 test accuracy:%89.50
#
# epoch:15700 loss:0.24764 accuracy:%88.92857 test loss:0.25725 test accuracy:%89.50
#
# epoch:15800 loss:0.24764 accuracy:%88.92857 test loss:0.25726 test accuracy:%89.50
#
# epoch:15900 loss:0.24763 accuracy:%88.92857 test loss:0.25723 test accuracy:%89.50
#
# epoch:16000 loss:0.24763 accuracy:%88.92857 test loss:0.25726 test accuracy:%89.50
#
# epoch:16100 loss:0.24763 accuracy:%88.92857 test loss:0.25725 test accuracy:%89.50
#
# epoch:16200 loss:0.24762 accuracy:%88.92857 test loss:0.25724 test accuracy:%89.50
#
# epoch:16300 loss:0.24762 accuracy:%88.92857 test loss:0.25724 test accuracy:%89.50
#
# epoch:16400 loss:0.24761 accuracy:%88.92857 test loss:0.25721 test accuracy:%89.50
#
# epoch:16500 loss:0.24761 accuracy:%88.92857 test loss:0.25723 test accuracy:%89.50
#
# epoch:16600 loss:0.24761 accuracy:%88.92857 test loss:0.25726 test accuracy:%89.50
#
# epoch:16700 loss:0.24761 accuracy:%88.92857 test loss:0.25726 test accuracy:%89.50
#
# epoch:16800 loss:0.24760 accuracy:%88.92857 test loss:0.25724 test accuracy:%89.50
#
# epoch:16900 loss:0.24760 accuracy:%88.92857 test loss:0.25725 test accuracy:%89.50
#
# epoch:17000 loss:0.24760 accuracy:%88.92857 test loss:0.25724 test accuracy:%89.50
#
# epoch:17100 loss:0.24759 accuracy:%88.92857 test loss:0.25721 test accuracy:%89.50
#
# epoch:17200 loss:0.24759 accuracy:%88.92857 test loss:0.25723 test accuracy:%89.50
#
# epoch:17300 loss:0.24759 accuracy:%88.92857 test loss:0.25722 test accuracy:%89.50
#
# epoch:17400 loss:0.24758 accuracy:%88.92857 test loss:0.25724 test accuracy:%89.50
#
# epoch:17500 loss:0.24758 accuracy:%88.92857 test loss:0.25722 test accuracy:%89.50
#
# epoch:17600 loss:0.24757 accuracy:%88.92857 test loss:0.25723 test accuracy:%89.50
#
# epoch:17700 loss:0.24757 accuracy:%88.92857 test loss:0.25719 test accuracy:%89.50
#
# epoch:17800 loss:0.24757 accuracy:%88.92857 test loss:0.25719 test accuracy:%89.50
#
# epoch:17900 loss:0.24756 accuracy:%88.92857 test loss:0.25721 test accuracy:%89.50
#
# epoch:18000 loss:0.24756 accuracy:%88.92857 test loss:0.25722 test accuracy:%89.50
#
# epoch:18100 loss:0.24756 accuracy:%88.92857 test loss:0.25720 test accuracy:%89.50
#
# epoch:18200 loss:0.24755 accuracy:%88.92857 test loss:0.25717 test accuracy:%89.50
#
# epoch:18300 loss:0.24755 accuracy:%88.92857 test loss:0.25718 test accuracy:%89.50
#
# epoch:18400 loss:0.24755 accuracy:%88.92857 test loss:0.25719 test accuracy:%89.50
#
# epoch:18500 loss:0.24754 accuracy:%88.92857 test loss:0.25722 test accuracy:%89.50
#
# epoch:18600 loss:0.24754 accuracy:%88.92857 test loss:0.25718 test accuracy:%89.50
#
# epoch:18700 loss:0.24754 accuracy:%88.92857 test loss:0.25720 test accuracy:%89.50
#
# epoch:18800 loss:0.24753 accuracy:%88.92857 test loss:0.25721 test accuracy:%89.50
#
# epoch:18900 loss:0.24753 accuracy:%88.92857 test loss:0.25720 test accuracy:%89.50
#
# epoch:19000 loss:0.24752 accuracy:%88.92857 test loss:0.25719 test accuracy:%89.50
#
# epoch:19100 loss:0.24752 accuracy:%88.92857 test loss:0.25717 test accuracy:%89.50
#
# epoch:19200 loss:0.24752 accuracy:%88.92857 test loss:0.25718 test accuracy:%89.50
#
# epoch:19300 loss:0.24752 accuracy:%88.92857 test loss:0.25720 test accuracy:%89.50
#
# epoch:19400 loss:0.24751 accuracy:%88.92857 test loss:0.25720 test accuracy:%89.50
#
# epoch:19500 loss:0.24751 accuracy:%88.92857 test loss:0.25720 test accuracy:%89.50
#
# epoch:19600 loss:0.24750 accuracy:%88.92857 test loss:0.25718 test accuracy:%89.50
#
# epoch:19700 loss:0.24750 accuracy:%88.92857 test loss:0.25719 test accuracy:%89.50
#
# epoch:19800 loss:0.24749 accuracy:%88.92857 test loss:0.25717 test accuracy:%89.50
#
# epoch:19900 loss:0.24749 accuracy:%88.92857 test loss:0.25717 test accuracy:%89.50
#
# epoch:20000 loss:0.24748 accuracy:%88.92857 test loss:0.25719 test accuracy:%89.50
